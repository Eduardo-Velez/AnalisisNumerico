# %% [markdown]
# # Integracion por el metodo de Simpsons 1/3

# %%
def simpsons13(f,a,b):
    return (b-a)*(f(a)+4*f((b-a)/2)+f(b))/6

# %%
f = lambda x : x**2
simpsons13(f,0,2)
# Out:
# 2.6666666666666665
